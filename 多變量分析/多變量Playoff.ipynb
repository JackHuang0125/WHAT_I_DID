# %%
data['Team_Abbreviation'].value_counts().index

# %%
teams = ['BOS', 'ATL', 'MIA', 'MIL', 'NYK', 'CLE', 'PHI', 'BRO',
         'DEN', 'MIN', 'GOL', 'SAC', 'LAC', 'MEM', 'PHO', 'LAL']

playoff = data[data['Team_Abbreviation'].isin(teams)]

# %%
position_counts = playoff['Position'].value_counts().reset_index()
position_counts.columns = ['Position', 'Count']

plt.figure(figsize=(6, 4))
sns.barplot(data=position_counts, x='Position', y='Count', hue='Position')
plt.xlabel("Position")
plt.ylabel("Count")
plt.show()
