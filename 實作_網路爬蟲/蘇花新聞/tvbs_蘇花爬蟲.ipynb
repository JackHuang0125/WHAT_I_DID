# %%
# import pandas as pd
# import requests as req
# from bs4 import BeautifulSoup as B, NavigableString, Tag, Comment, Doctype
# import time

# links = []
# titles = []
# for i in range(1, 49):
#     url = f'https://news.tvbs.com.tw/news/searchresult/%E8%98%87%E8%8A%B1%E5%85%AC%E8%B7%AF/news/{i}'
#     resp = req.get(url)
#     if resp.status_code != 200 :
#         print('Error status_code')
#     else:
#         soup = B(resp.text, 'html.parser')
#         sites = soup.find_all('div', class_='list')
#         for s in sites:
#             ul_ = s.find('ul')
#             if not ul_:
#                 continue
#             for li_ in ul_.find_all('li'):
#                 a_tag = li_.find('a', href=True)
#                 h2_tag = li_.find('h2', class_='txt')
#                 if a_tag and h2_tag:
#                     link = a_tag['href']
#                     title = h2_tag.get_text(strip=True)
#                     links.append(link)
#                     titles.append(title)
    # time.sleep(1)

# data = pd.DataFrame({'Link': links, 'Title': titles})
# data.to_csv('tvbs_蘇花公路.csv', index=False)

# %%
# data = pd.read_csv('tvbs_蘇花公路.csv')

# %%
# data.shape

# %%
# data['Context'] = ''; data['PublishTime'] = ''

# failed_urls = []

# for i, url in enumerate(data['Link']):
#     print(f'[{i+1}/{len(data)}] 處理中：{url}')

#     try:
#         resp = req.get(url)

#         if resp.status_code != 200:
#             print(f'無法存取：{resp.status_code}')
#             data.at[i, 'Context'] = ''
#             data.at[i, 'PublishTime'] = ''
#             failed_urls.append(url)
#             continue

#         soup = B(resp.text, 'html.parser')

#         article_div = soup.find('div', id='news_detail_div') or soup.find('div', class_='article_content')
#         context = []
    
#         if isinstance(article_div, Tag):
#             for node in article_div.descendants:
#                 if getattr(node, 'get', lambda x: None)('id') == 'article-end-marker':
#                     break
#                 if isinstance(node, NavigableString) and not isinstance(node, (Comment, Doctype)):
#                     text = node.strip()
#                     if text:
#                         context.append(text)

#             full_text = '\n'.join(context)
#             data.at[i, 'Context'] = full_text
#         else:
#             print('⚠️ 找不到 <div class="article_content">')
#             data.at[i, 'Context'] = ''
#             failed_urls.append(url)

#         author_div = soup.find('div', class_='author')
#         pub_time = ''

#         if author_div:
#             text = author_div.get_text(separator='\n', strip=True)
#             pub_line = next((line for line in text.split('\n') if '發佈時間' in line), '')
#             pub_time = pub_line.replace('發佈時間：', '').strip()
#         else:
#             pub_node = soup.find(string=lambda t: '發佈時間' in t)
#             if pub_node:
#                 pub_time = pub_node.replace('發佈時間：', '').strip()

#         data.at[i, 'PublishTime'] = pub_time

#     except Exception as e:
#         print(f'發生錯誤:{e}')
#         data.at[i, 'Context'] = ''
#         data.at[i, 'PublishTime'] = ''
#         failed_urls.append(url)

#     data.to_csv('tvbs_蘇花公路_temp.csv', index=False)
#     time.sleep(1) 

# data.to_csv('tvbs_蘇花公路_full.csv', index=False)
# with open('tvbs_蘇花公路_failed.txt', 'w', encoding='utf-8') as f:
#     for url in failed_urls:
#         f.write(url+'\n')
# print('全部完成, 已儲存完整資料和失敗網址')

# %%
df = pd.read_csv('tvbs_蘇花公路_full.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1183 entries, 0 to 1182
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Link         1183 non-null   object
#  1   Title        1183 non-null   object
#  2   Context      1177 non-null   object
#  3   PublishTime  1178 non-null   object
# dtypes: object(4)
# memory usage: 37.1+ KB

# %%
# import pandas as pd
# import requests as req
# from bs4 import BeautifulSoup as B, NavigableString, Tag, Comment, Doctype
# import time

# links = []
# titles = []
# for i in range(1, 17):
#     url = f'https://news.tvbs.com.tw/news/searchresult/%E8%98%87%E8%8A%B1%E6%94%B9/news/{i}'
#     resp = req.get(url)
#     if resp.status_code != 200 :
#         print('Error status_code')
#     else:
#         soup = B(resp.text, 'html.parser')
#         sites = soup.find_all('div', class_='list')
#         for s in sites:
#             ul_ = s.find('ul')
#             if not ul_:
#                 continue
#             for li_ in ul_.find_all('li'):
#                 a_tag = li_.find('a', href=True)
#                 h2_tag = li_.find('h2', class_='txt')
#                 if a_tag and h2_tag:
#                     link = a_tag['href']
#                     title = h2_tag.get_text(strip=True)
#                     links.append(link)
#                     titles.append(title)
#     time.sleep(1)
# data = pd.DataFrame({'Link': links, 'Title': titles})
# data.to_csv('tvbs_蘇花改.csv', index=False)

# %%
data = pd.read_csv('tvbs_蘇花改.csv')

# %%
data.shape
# Out:
# (383, 2)

# %%
data['Context'] = ''; data['PublishTime'] = ''

failed_urls = []

for i, url in enumerate(data['Link']):
    print(f'[{i+1}/{len(data)}] 處理中：{url}')

    try:
        resp = req.get(url)

        if resp.status_code != 200:
            print(f'無法存取：{resp.status_code}')
            data.at[i, 'Context'] = ''
            data.at[i, 'PublishTime'] = ''
            failed_urls.append(url)
            continue

        soup = B(resp.text, 'html.parser')

        article_div = soup.find('div', id='news_detail_div') or soup.find('div', class_='article_content') or soup.find('div', class_="entry-content")
        context = []
    
        if isinstance(article_div, Tag):
            for node in article_div.descendants:
                if getattr(node, 'get', lambda x: None)('id') == 'article-end-marker':
                    break
                if isinstance(node, NavigableString) and not isinstance(node, (Comment, Doctype)):
                    text = node.strip()
                    if text:
                        context.append(text)

            full_text = '\n'.join(context)
            data.at[i, 'Context'] = full_text
        else:
            print('⚠️ 找不到 <div class="article_content">')
            data.at[i, 'Context'] = ''
            failed_urls.append(url)

        author_div = soup.find('div', class_='author')
        pub_time = ''

        if author_div:
            text = author_div.get_text(separator='\n', strip=True)
            pub_line = next((line for line in text.split('\n') if '發佈時間' in line), '')
            pub_time = pub_line.replace('發佈時間：', '').strip()
        else:
            pub_node = soup.find(string=lambda t: '發佈時間' in t)
            if pub_node:
                pub_time = pub_node.replace('發佈時間：', '').strip()

        data.at[i, 'PublishTime'] = pub_time

    except Exception as e:
        print(f'發生錯誤:{e}')
        data.at[i, 'Context'] = ''
        data.at[i, 'PublishTime'] = ''
        failed_urls.append(url)

    data.to_csv('tvbs_蘇花改_temp.csv', index=False)
    time.sleep(1) 

data.to_csv('tvbs_蘇花改_full.csv', index=False)
with open('tvbs_蘇花改_failed.txt', 'w', encoding='utf-8') as f:
    for url in failed_urls:
        f.write(url+'\n')
print('全部完成, 已儲存完整資料和失敗網址')
# Out:
# [1/383] 處理中：https://news.tvbs.com.tw/life/2868397
# [351/383] 處理中：https://news.tvbs.com.tw/politics/651761
# [352/383] 處理中：https://news.tvbs.com.tw/local/642472
# [353/383] 處理中：https://news.tvbs.com.tw/life/625915
# [354/383] 處理中：https://news.tvbs.com.tw/life/615887
# [355/383] 處理中：https://news.tvbs.com.tw/life/520756
# [356/383] 處理中：https://news.tvbs.com.tw/tech/520193
# [357/383] 處理中：https://news.tvbs.com.tw/local/505774
# [358/383] 處理中：https://news.tvbs.com.tw/life/505703
# [359/383] 處理中：https://news.tvbs.com.tw/life/217545
# [360/383] 處理中：https://news.tvbs.com.tw/local/4286
# [361/383] 處理中：https://news.tvbs.com.tw/local/40388
# [362/383] 處理中：https://news.tvbs.com.tw/life/39109
# [363/383] 處理中：https://news.tvbs.com.tw/politics/35741
# [364/383] 處理中：https://news.tvbs.com.tw/life/67399
# [365/383] 處理中：https://news.tvbs.com.tw/life/43922
# [366/383] 處理中：https://news.tvbs.com.tw/life/111673
# [367/383] 處理中：https://news.tvbs.com.tw/life/111678
# [368/383] 處理中：https://news.tvbs.com.tw/politics/111090
# [369/383] 處理中：https://news.tvbs.com.tw/politics/110975
# [370/383] 處理中：https://news.tvbs.com.tw/politics/110983
# [371/383] 處理中：https://news.tvbs.com.tw/local/110986
# [372/383] 處理中：https://news.tvbs.com.tw/politics/110811
# [373/383] 處理中：https://news.tvbs.com.tw/politics/110836
# [374/383] 處理中：https://news.tvbs.com.tw/politics/110863
# [375/383] 處理中：https://news.tvbs.com.tw/politics/110869
# [376/383] 處理中：https://news.tvbs.com.tw/politics/110754
# [377/383] 處理中：https://news.tvbs.com.tw/politics/110505
# [378/383] 處理中：https://news.tvbs.com.tw/politics/110586
# [379/383] 處理中：https://news.tvbs.com.tw/politics/110423
# [380/383] 處理中：https://news.tvbs.com.tw/local/110301
# [381/383] 處理中：https://news.tvbs.com.tw/politics/110254
# [382/383] 處理中：https://news.tvbs.com.tw/politics/110143
# [383/383] 處理中：https://news.tvbs.com.tw/local/110018
# 全部完成, 已儲存完整資料和失敗網址

# %%
# import pandas as pd
# import requests as req
# from bs4 import BeautifulSoup as B, NavigableString, Tag, Comment, Doctype
# import time

# links = []
# titles = []
# for i in range(1, 6):
#     url = f'https://news.tvbs.com.tw/news/searchresult/%E8%98%87%E8%8A%B1%E9%AB%98/news/{i}'
#     resp = req.get(url)
#     if resp.status_code != 200 :
#         print('Error status_code')
#     else:
#         soup = B(resp.text, 'html.parser')
#         sites = soup.find_all('div', class_='list')
#         for s in sites:
#             ul_ = s.find('ul')
#             if not ul_:
#                 continue
#             for li_ in ul_.find_all('li'):
#                 a_tag = li_.find('a', href=True)
#                 h2_tag = li_.find('h2', class_='txt')
#                 if a_tag and h2_tag:
#                     link = a_tag['href']
#                     title = h2_tag.get_text(strip=True)
#                     links.append(link)
#                     titles.append(title)
#     time.sleep(1)
# data = pd.DataFrame({'Link': links, 'Title': titles})
# data.to_csv('tvbs_蘇花高.csv', index=False)

# %%
# data = pd.read_csv('tvbs_蘇花高.csv')

# %%
# data.shape
# Out:
# (118, 2)

# %%
# data['Context'] = ''; data['PublishTime'] = ''

# failed_urls = []

# for i, url in enumerate(data['Link']):
#     print(f'[{i+1}/{len(data)}] 處理中：{url}')

#     try:
#         resp = req.get(url)

#         if resp.status_code != 200:
#             print(f'無法存取：{resp.status_code}')
#             data.at[i, 'Context'] = ''
#             data.at[i, 'PublishTime'] = ''
#             failed_urls.append(url)
#             continue

#         soup = B(resp.text, 'html.parser')

#         article_div = soup.find('div', id='news_detail_div') or soup.find('div', class_='article_content')
#         context = []
    
#         if isinstance(article_div, Tag):
#             for node in article_div.descendants:
#                 if getattr(node, 'get', lambda x: None)('id') == 'article-end-marker':
#                     break
#                 if isinstance(node, NavigableString) and not isinstance(node, (Comment, Doctype)):
#                     text = node.strip()
#                     if text:
#                         context.append(text)

#             full_text = '\n'.join(context)
#             data.at[i, 'Context'] = full_text
#         else:
#             print('⚠️ 找不到 <div class="article_content">')
#             data.at[i, 'Context'] = ''
#             failed_urls.append(url)

#         author_div = soup.find('div', class_='author')
#         pub_time = ''

#         if author_div:
#             text = author_div.get_text(separator='\n', strip=True)
#             pub_line = next((line for line in text.split('\n') if '發佈時間' in line), '')
#             pub_time = pub_line.replace('發佈時間：', '').strip()
#         else:
#             pub_node = soup.find(string=lambda t: '發佈時間' in t)
#             if pub_node:
#                 pub_time = pub_node.replace('發佈時間：', '').strip()

#         data.at[i, 'PublishTime'] = pub_time

#     except Exception as e:
#         print(f'發生錯誤:{e}')
#         data.at[i, 'Context'] = ''
#         data.at[i, 'PublishTime'] = ''
#         failed_urls.append(url)

#     data.to_csv('tvbs_蘇花高_temp.csv', index=False)
#     time.sleep(1) 

# data.to_csv('tvbs_蘇花高_full.csv', index=False)
# with open('tvbs_蘇花高_failed.txt', 'w', encoding='utf-8') as f:
#     for url in failed_urls:
#         f.write(url+'\n')
# print('全部完成, 已儲存完整資料和失敗網址')
# Out:
# [1/118] 處理中：https://news.tvbs.com.tw/politics/2659217
# [2/118] 處理中：https://news.tvbs.com.tw/local/1487525
# [3/118] 處理中：https://news.tvbs.com.tw/local/1478442
# [4/118] 處理中：https://news.tvbs.com.tw/life/1227644
# [5/118] 處理中：https://news.tvbs.com.tw/local/1016093
# [6/118] 處理中：https://news.tvbs.com.tw/life/896195
# [7/118] 處理中：https://news.tvbs.com.tw/local/870888
# [8/118] 處理中：https://news.tvbs.com.tw/life/853924
# [9/118] 處理中：https://news.tvbs.com.tw/local/702216
# [10/118] 處理中：https://news.tvbs.com.tw/local/565829
# [11/118] 處理中：https://news.tvbs.com.tw/life/67399
# [12/118] 處理中：https://news.tvbs.com.tw/life/110769
# [13/118] 處理中：https://news.tvbs.com.tw/politics/110505
# [14/118] 處理中：https://news.tvbs.com.tw/local/110301
# [15/118] 處理中：https://news.tvbs.com.tw/local/110218
# [16/118] 處理中：https://news.tvbs.com.tw/politics/110253
# [17/118] 處理中：https://news.tvbs.com.tw/politics/110254
# [18/118] 處理中：https://news.tvbs.com.tw/local/110059
