# %% [markdown]
# Meeting 0731(Thr). Next time  0807 13:10-15:00
#
# #Discussion
# 1. GAP clusters to classifier
# 2. 資料科學漫步
# 3. 共同指導
#
# #Todo
# 1. GAP clusters n1-nk, do confusion matrix, weak classifier(machine learning), variables correlation
# 2. Do classifier on the data first,  and then do the GAP
# 3. Find some manufacturing process data and its reference

# %% [markdown]
# ### GAP

# %% [markdown]
# data = pd.read_csv(r"data路徑")
#
# data = data.drop(columns=[跟x無關的]) 要跑GAP, no_Y就這樣存
#
# data.to_csv('data.csv', sep='\t', encoding='utf-8', index=False) 整筆這樣存, 後續再改data儲存後跑GAP才不會有問題
